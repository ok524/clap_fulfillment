# %%
import importlib
import util
importlib.reload(util)
from util import *

# %%
import pandas as pd
from nltk import ngrams
from IPython.core.display import display, HTML

# %% [markdown]
# # Identify Job Ads Post Structure

# %% [markdown]
# last update: 2020-03-20
#
# ### Assumption:
# - Sentences which belong the same section are in sequence.
# - Each section only occur exactly only one time.
#
# ### Advantages:
# 1. Ordering of different sections does not matter.
# 2. May apply to different job ads websites.
#
# ### Limitataion:
# 1. Some sections may have overlapping issues. E.g. Responsibilities and Requirements.
# 2. Chinese Characters have not yet been dealt with.
#
# ### What's next:
# 1. Expand the tagging to sentence-wise or paragraph-wise
# 2. Tokenizr Chinese Characters to support job ads in Chinese

# %% [markdown]
# # Training Stage: Load training data

# %%
df = get_df('./jobsdb_dump_first100.json')

# %%
idx = 2
text = df["jobDetail"][idx]["jobDescription"]
pt = PrepText(text)
ajson = pt.get_variables()

# %%
jds = [PrepText(x["jobDescription"]).get_variables()["lower_text"] for x in df["jobDetail"]]
# Out:
# [Warn]<set_lower_text>: Contains non latin characters.
# [Warn]<set_lower_text>: Contains non latin characters.
# [Warn]<set_lower_text>: Contains non latin characters.
# [Warn]<set_lower_text>: Contains non latin characters.
# [Warn]<set_lower_text>: Contains non latin characters.

# %% [markdown]
# # Training Stage: NGram of all texts

# %%
# Ngram
sentence = ' '.join(jds)
sentence = sentence.replace("   ", " ").replace("  ", " ").replace("  ", " ").replace("  ", " ").strip("\n\r\t ")
sentence = sentence.replace("...", ".").replace(". . ", ". ").replace(". . ", ". ").replace(". . ", ". ")
n = 2
sixgrams = ngrams(sentence.split(), n)
gram_arr = list(set(sixgrams))

print(f'Token counts: {len(list(set(gram_arr)))}')

result = []
for idx in range(len(gram_arr)):
    word = ' '.join(gram_arr[idx])
    aobj = (word, sentence.count(word))
    
    result.append(aobj)

all_2grams = sorted(result, key=lambda x: x[1], reverse=True)
all_2grams
# Out:
# Token counts: 11873
# [('will be', 121),
#  ('or a', 107),
#  ('and a', 103),
#  ('experience in', 91),
#  ('on a', 81),
#  ('in a', 69),
#  ('is a', 66),
#  ('in the', 64),
#  ('. to', 61),
#  ('. in', 61),
#  ('on an', 59),
#  ('for a', 56),
#  ('. we', 56),
#  ('. good', 56),
#  ('to the', 56),
#  ('. requirement', 53),
#  ('or recruitment', 47),
#  ('for recruitment', 46),
#  ('to a', 43),
#  ('personal data', 42),
#  ('to work', 42),
#  ('used for', 41),
#  ('apply now', 39),
#  ('related discipline', 39),
#  ('recruitment purpose', 37),
#  ('. requirements:.', 37),
#  ('be used', 37),
#  ('english and', 36),
#  ('. interested', 35),
#  ('please send', 35),
#  ('command of', 35),
#  ('expected salary', 35),
#  ('able to', 34),
#  ('. prepare', 34),
#  ('looking for', 33),
#  ('for the', 33),
#  ('. assist', 33),
#  ('good command', 33),
#  ('responsible for', 32),
#  ('or above', 32),
#  ('and chinese', 32),
#  ('our client', 32),
#  ('data collected', 31),
#  ('of the', 31),
#  ('be consider', 30),
#  ('of a', 30),
#  ('send your', 30),
#  ('be considered', 29),
#  ('r and', 29),
#  ('assist in', 29),
#  ('or related', 29),
#  ('. please', 28),
#  ('related disciplines', 28),
#  ('with a', 27),
#  ('work in', 27),
#  ('. job', 27),
#  ('is an', 27),
#  ('interested parties', 26),
#  ('. the', 26),
#  ('and expect', 26),
#  ('. strong', 25),
#  ('collected will', 25),
#  ('an advantage', 25),
#  ('. knowledge', 24),
#  ('communication skill', 24),
#  ('. min', 24),
#  ('. work', 24),
#  ('and written', 24),
#  ('full resume', 24),
#  ('. excellent', 24),
#  ('the right', 24),
#  ('and an', 23),
#  ('ability to', 23),
#  ('. degree', 23),
#  ('salary and', 23),
#  ('with the', 23),
#  ('be a', 23),
#  ('and expected', 23),
#  ('is preferred', 22),
#  ('. our', 22),
#  ('degree holder', 22),
#  ('we offer', 22),
#  ('. responsibilities:', 21),
#  ('remuneration package', 21),
#  ('working experience', 21),
#  ('human resource', 21),
#  ('client is', 21),
#  ('as a', 21),
#  ('parties please', 21),
#  ('spoken and', 21),
#  ('right candidate', 20),
#  ('years of', 20),
#  ('visit our', 20),
#  ('. experience', 20),
#  ('are an', 20),
#  ('human resources', 20),
#  ('"apply now"', 20),
#  ('a team', 20),
#  ('or more', 20),
#  ('communication skills', 20),
#  ('related disciplines.', 20),
#  ('. minimum', 19),
#  ('. handle', 19),
#  ('knowledge in', 19),
#  ('spoken english', 19),
#  ('our web', 19),
#  ('their application', 19),
#  (': .', 19),
#  ('purpose only', 18),
#  ('please visit', 18),
#  ('for more', 18),
#  ('3 year', 18),
#  ('to join', 18),
#  ('purposes only', 18),
#  ('degree in', 18),
#  ('under pressure', 18),
#  ('we are', 18),
#  ('at least', 18),
#  ('to ensure', 17),
#  ('work with', 17),
#  ('. responsible', 17),
#  ('their applications', 17),
#  ('3 years', 17),
#  ('5 years', 17),
#  ('our website', 17),
#  ('2 years', 16),
#  ('closely with', 16),
#  ('the company', 16),
#  ('resume with', 16),
#  ('written english', 16),
#  ('hong kong', 16),
#  ('work under', 16),
#  ('experience will', 16),
#  ('is preferred.', 16),
#  ('consider their', 16),
#  ('. perform', 16),
#  ('you will', 16),
#  ('knowledge of', 16),
#  ('or degree', 16),
#  ('such as', 16),
#  ('your full', 16),
#  ('purposes only.', 15),
#  ('be kept', 15),
#  ('computer science', 15),
#  ('written and', 15),
#  ('and work', 15),
#  ('may consider', 15),
#  ('proficient in', 15),
#  (':. degree', 15),
#  ('ms office', 15),
#  ('please click', 15),
#  ('join the', 15),
#  ('. about', 14),
#  ('and manage', 14),
#  ('to be', 14),
#  ('ad hoc', 14),
#  ('they are', 14),
#  ('communication and', 14),
#  ('an advantage.', 14),
#  ('on experience', 14),
#  ('are looking', 14),
#  ('in accounting', 14),
#  ('applications unsuccessful.', 14),
#  ('above in', 14),
#  ('in ms', 14),
#  ('less experience', 14),
#  ('be treated', 14),
#  ('and be', 13),
#  ('bachelor degree', 13),
#  ('for an', 13),
#  ('holder in', 13),
#  ('and provide', 13),
#  ('to apply', 13),
#  ('and able', 13),
#  ('work independently', 13),
#  ('offer a', 13),
#  ('relevant experience', 13),
#  ('if you', 13),
#  ('now looking', 13),
#  ('considered as', 13),
#  ('proficiency in', 13),
#  ('in strict', 12),
#  ('. if', 12),
#  ('or other', 12),
#  ('right candidate.', 12),
#  ('purpose only.', 12),
#  ('and business', 12),
#  ('and spoken', 12),
#  ('recruitment purposes', 12),
#  ('on the', 12),
#  ('work closely', 12),
#  ('your application', 12),
#  ('salary to', 12),
#  ('candidates will', 12),
#  ('a plus', 12),
#  ('it security', 12),
#  ('in computer', 12),
#  ('. coordinate', 12),
#  ('and mandarin', 12),
#  ('be responsible', 12),
#  ('attractive remuneration', 11),
#  ('provided by', 11),
#  ('treated in', 11),
#  ('about the', 11),
#  ('only. a', 11),
#  ('to manage', 11),
#  ('liaise with', 11),
#  (':. bachelor', 11),
#  ('with good', 11),
#  ('data provided', 11),
#  ('of written', 11),
#  ('join their', 11),
#  ('and used', 11),
#  ('design and', 11),
#  ('current and', 11),
#  ('applications will', 11),
#  ('of our', 11),
#  ('your resume', 11),
#  ('this role', 11),
#  ('for product', 11),
#  ('fringe benefits', 11),
#  ('with less', 11),
#  ('team player', 11),
#  ('. diploma', 11),
#  ('strict confidence', 11),
#  ('candidates with', 11),
#  ('in business', 11),
#  ('the following', 10),
#  ('or equivalent', 10),
#  ('attractive salary', 10),
#  ('be considered.', 10),
#  ('from the', 10),
#  ('be an', 10),
#  ('is highly', 10),
#  ('other ad', 10),
#  ('by clicking', 10),
#  ('of spoken', 10),
#  ('. able', 10),
#  ('. conduct', 10),
#  ('invited for', 10),
#  ('. manage', 10),
#  ('at a', 10),
#  ('interview within', 10),
#  ('. university', 10),
#  ('in it', 10),
#  ('to assist', 10),
#  ('interpersonal skill', 10),
#  ('the person', 10),
#  ('good communication', 10),
#  ('confidence and', 10),
#  ('. develop', 10),
#  ('our website:', 10),
#  ('highly preferred', 10),
#  ('is required', 10),
#  ('competitive remuneration', 10),
#  ('in an', 10),
#  ('and send', 10),
#  ('you are', 10),
#  ('8 year', 10),
#  ('diploma or', 9),
#  ('in your', 9),
#  ('and fringe', 9),
#  ('only for', 9),
#  ('the reference', 9),
#  ('under pressure.', 9),
#  ('available is', 9),
#  ('not invited', 9),
#  ('em and', 9),
#  ('and chinese.', 9),
#  ('requirements:. degree', 9),
#  ('due to', 9),
#  ('would be', 9),
#  ('about our', 9),
#  ('career prospect', 9),
#  ('team to', 9),
#  ('willing to', 9),
#  ('5 days', 9),
#  ('present and', 9),
#  ('an equal', 9),
#  ('development and', 9),
#  ('and develop', 9),
#  ('. requirements.', 9),
#  ('applicants will', 9),
#  ('opportunity employer', 9),
#  ('within the', 9),
#  ('equal opportunity', 9),
#  ('click "apply', 9),
#  ('and hand', 9),
#  ('all personal', 9),
#  ('please apply', 9),
#  ('applicants not', 9),
#  ('who are', 9),
#  ('the role', 9),
#  ('as well', 9),
#  ('8 years', 9),
#  ('well as', 9),
#  ('confidential and', 9),
#  ('and communication', 9),
#  ('and ad', 9),
#  ('be provided', 9),
#  ('including putonghua', 9),
#  ('interested in', 9),
#  ('engineering or', 8),
#  ('the project', 8),
#  ('team of', 8),
#  ('or equivalent.', 8),
#  ('development of', 8),
#  ('candidate. interested', 8),
#  ('by job', 8),
#  ('and maintain', 8),
#  ('on or', 8),
#  ('strong sense', 8),
#  ('strong communication', 8),
#  ('within 6', 8),
#  ('review and', 8),
#  ('and other', 8),
#  ('be offered', 8),
#  ('provide a', 8),
#  ('more information', 8),
#  ('related purposes', 8),
#  ('excellent communication', 8),
#  ('with internal', 8),
#  ('hands on', 8),
#  ('and service', 8),
#  ('as assigned', 8),
#  ('cantonese and', 8),
#  ('job description', 8),
#  ('kept confidential', 8),
#  ('the group', 8),
#  ('sense of', 8),
#  ('and implement', 8),
#  ('are now', 8),
#  ('discretionary bonus', 8),
#  ('full set', 8),
#  ('parties, please', 8),
#  ('skills and', 8),
#  ('and monitor', 8),
#  ('client, a', 8),
#  ('with full', 8),
#  ('up and', 8),
#  ('minimum 5', 8),
#  ('services to', 8),
#  ('5-day work', 8),
#  ('participate in', 8),
#  ('to support', 8),
#  ('on system', 8),
#  ('fresh graduate', 8),
#  ('weeks may', 7),
#  ('what you', 7),
#  ('work and', 7),
#  ('with strong', 7),
#  ('internal and', 7),
#  ('immediate available', 7),
#  ('and external', 7),
#  ('6 weeks', 7),
#  ('of responsibility', 7),
#  ('familiar with', 7),
#  ('in english', 7),
#  ('university graduate', 7),
#  ('preferred .', 7),
#  ('including putonghua.', 7),
#  ('and can', 7),
#  ('skill and', 7),
#  ('communication skills.', 7),
#  ('and perform', 7),
#  ('the business', 7),
#  ('and chinese,', 7),
#  ('degree or', 7),
#  ('excellent career', 7),
#  ('are not', 7),
#  ('presentation skills', 7),
#  ('chinese word', 7),
#  ('and financial', 7),
#  ('or it', 7),
#  ('or above.', 7),
#  ('excellent interpersonal', 7),
#  ('and the', 7),
#  ('may be', 7),
#  ('and support', 7),
#  ('science or', 7),
#  ('job requirements:', 7),
#  ('information technology', 7),
#  ('solid experience', 7),
#  ('and presentation', 7),
#  ('of work', 7),
#  ('problem solving', 7),
#  ('a plus.', 7),
#  ('resume to', 7),
#  ('internal control', 7),
#  ('of accounts', 7),
#  ('set of', 7),
#  ('quality requirement', 7),
#  ('business development', 7),
#  ('system and', 7),
#  ('only. applicants', 7),
#  ('develop a', 7),
#  ('and english', 7),
#  ('english, cantonese', 7),
#  ('interpersonal and', 7),
#  ('interpersonal skills', 7),
#  ('"apply now".', 7),
#  ('good interpersonal', 7),
#  ('a high', 7),
#  ('sales team', 7),
#  ('management reports', 7),
#  ('this is', 7),
#  ('technical support', 7),
#  ('in both', 7),
#  ('an app', 7),
#  ('applicants who', 7),
#  ('“apply now”', 7),
#  ('job applicants', 7),
#  ('with more', 7),
#  ('requirements:. bachelor', 7),
#  ('report to', 7),
#  ('& chinese', 7),
#  ('high caliber', 7),
#  ('interested parties,', 7),
#  ('fluent in', 7),
#  ('and analysis', 7),
#  ('minimum 3', 7),
#  ('and management', 7),
#  ('a competitive', 7),
#  ('for interview', 7),
#  ('years working', 7),
#  ('other related', 7),
#  ('word, excel', 7),
#  ('. support', 7),
#  ('hoc assignment', 7),
#  ('to perform', 7),
#  ('need to', 7),
#  ('responsibilities: .', 7),
#  ('full resume,', 7),
#  ('of english', 7),
#  ('and network', 7),
#  ('support to', 7),
#  ('management system', 7),
#  ('preferably in', 7),
#  ('chinese, including', 7),
#  ('and availability', 7),
#  ('more than', 6),
#  ('our client,', 6),
#  ('assigned by', 6),
#  ('and meet', 6),
#  ('career prospects', 6),
#  ('via "apply', 6),
#  ('please contact', 6),
#  ('but not', 6),
#  ('reference number', 6),
#  ('coordinate with', 6),
#  ('now" or', 6),
#  ('unsuccessful. all', 6),
#  ('also be', 6),
#  ('career development', 6),
#  ('is now', 6),
#  ('. build', 6),
#  ('candidate with', 6),
#  ('of both', 6),
#  ('offer attractive', 6),
#  ('and strong', 6),
#  ('have a', 6),
#  ('a confidential', 6),
#  ('good team', 6),
#  ('days work', 6),
#  ('project management', 6),
#  ('finance or', 6),
#  ('relevant work', 6),
#  ('disciplines. a', 6),
#  ('network in', 6),
#  ('analytical skill', 6),
#  ('your application.', 6),
#  ('strong analytical', 6),
#  ('apply online', 6),
#  ('with different', 6),
#  ('l work', 6),
#  ('candidates. please', 6),
#  ('are the', 6),
#  ('ensure the', 6),
#  ('graduate in', 6),
#  ('and problem', 6),
#  ('cv to', 6),
#  ('the company.', 6),
#  ('and tax', 6),
#  ('reporting and', 6),
#  ('years relevant', 6),
#  ('end closing', 6),
#  ('available date', 6),
#  ('by us', 6),
#  ('and experience', 6),
#  ('to meet', 6),
#  ('a senior', 6),
#  ('requirements:. university', 6),
#  ('or any', 6),
#  ('detailed resume', 6),
#  ('planning and', 6),
#  ('prepare monthly', 6),
#  ('information and', 6),
#  ('work on', 6),
#  ('kowloon bay', 6),
#  ('email address', 6),
#  ('and project', 6),
#  ('accounting or', 6),
#  ('relationship with', 6),
#  ('skills. good', 6),
#  ('word processing', 6),
#  ('offer 5', 6),
#  ('and product', 6),
#  ('ng at', 6),
#  ('solutions to', 6),
#  ('in order', 6),
#  ('according to', 6),
#  ('from us', 6),
#  ('head of', 6),
#  ('both spoken', 6),
#  ('fast growing', 6),
#  ('button. for', 6),
#  ('duties as', 6),
#  ('responsibilities:. responsible', 6),
#  ('with other', 6),
#  ('job responsibilities:', 6),
#  ('right candidates.', 6),
#  ('be notified', 6),
#  ('offered to', 6),
#  ('. this', 6),
#  ('solving skill', 6),
#  ('package and', 6),
#  ('user requirement', 6),
#  ('analysis and', 6),
#  ('for system', 6),
#  ('and safe', 6),
#  ('your updated', 6),
#  ('the world', 6),
#  ('work week', 6),
#  ('in spoken', 6),
#  ('and mandarin.', 6),
#  ('management to', 6),
#  ('following position:.', 6),
#  ('hong kong.', 6),
#  ('hoc projects', 6),
#  ('us within', 6),
#  ('as required', 6),
#  ('system development', 6),
#  ('to us', 6),
#  ('confidential discussion', 6),
#  ('years’ experience', 6),
#  ('and report', 6),
#  ('and services', 6),
#  ('in accounting,', 6),
#  ('order to', 6),
#  ('em in', 6),
#  ('development opportunities', 6),
#  ('all levels', 6),
#  ('hoc assignments', 6),
#  ('understanding of', 6),
#  ('and will', 6),
#  ('and customer', 6),
#  ('for any', 5),
#  ('with current', 5),
#  ('to learn', 5),
#  ('to provide', 5),
#  ('with excellent', 5),
#  ('at 2957', 5),
#  ('lead a', 5),
#  ('disciplines. min', 5),
#  ('act as', 5),
#  ('independent and', 5),
#  ('5+ years', 5),
#  ('drawn, expected', 5),
#  ('to prepare', 5),
#  ('by the', 5),
#  ('date of', 5),
#  ('only be', 5),
#  ('strong technical', 5),
#  ('is required.', 5),
#  ('with client', 5),
#  ('financial information', 5),
#  ('a good', 5),
#  ('projects and', 5),
#  ('work experience', 5),
#  ('medical insurance', 5),
#  ('click the', 5),
#  ('expected salaries', 5),
#  ('job requirements:.', 5),
#  ('(personal data', 5),
#  ('and achieve', 5),
#  ('will also', 5),
#  ('job requirements.', 5),
#  ('experience with', 5),
#  ('to contact', 5),
#  ('team and', 5),
#  ('bond west', 5),
#  ('with expected', 5),
#  ('and excel.', 5),
#  ('opportunity, please', 5),
#  ('support the', 5),
#  ('website at', 5),
#  ('co., ltd.', 5),
#  ('website: www.bondwest.com.', 5),
#  ('apply with', 5),
#  ('more about', 5),
#  ('not hear', 5),
#  ('hands-on experience', 5),
#  ('last drawn,', 5),
#  ('and prepare', 5),
#  ('financial reports', 5),
#  ('and or', 5),
#  ('quality requirements', 5),
#  ('information about', 5),
#  ('availability to', 5),
#  ('any query,', 5),
#  ('preparation of', 5),
#  ('accordance with', 5),
#  ('or via', 5),
#  ('the human', 5),
#  ('is only', 5),
#  ('well organized', 5),
#  ('offer competitive', 5),
#  ('business administration', 5),
#  ('knowledge on', 5),
#  ('and english.', 5),
#  ('annual leave', 5),
#  ('manager to', 5),
#  ('identify and', 5),
#  ('feel free', 5),
#  ('accounting, finance', 5),
#  ('financial analysis', 5),
#  ('quote the', 5),
#  ('consider as', 5),
#  ('finance, accounting', 5),
#  ('develop and', 5),
#  ('and software', 5),
#  ('in financial', 5),
#  ('least 3', 5),
#  ('experience of', 5),
#  ('& spoken', 5),
#  ('to bond', 5),
#  ('holder or', 5),
#  ('more experience', 5),
#  ('salary package', 5),
#  ('employer and', 5),
#  ('applications from', 5),
#  ('or for', 5),
#  ('to other', 5),
#  ('knowledge and', 5),
#  ('successful candidates.', 5),
#  ('collected is', 5),
#  ('management and', 5),
#  ('the role:.', 5),
#  ('and assist', 5),
#  ('skills in', 5),
#  ('both written', 5),
#  ('here" or', 5),
#  ('carmen.ching @springasia.com.', 5),
#  ('in banking', 5),
#  ('all qualified', 5),
#  ('send in', 5),
#  ('self-motivated and', 5),
#  ('coordinate and', 5),
#  ('kowloon bay,', 5),
#  ('and handle', 5),
#  ('to 2', 5),
#  ('clicking "apply', 5),
#  ('external parties', 5),
#  ('via "apply"', 5),
#  ('daily operation', 5),
#  ('from all', 5),
#  ('maintain a', 5),
#  ('and welcome', 5),
#  ('provided will', 5),
#  ('in finance', 5),
#  ('your cv', 5),
#  ('power. point', 5),
#  ('in accordance', 5),
#  ('solution for', 5),
#  ('hoc duties', 5),
#  ('a world', 5),
#  ('fax to', 5),
#  ('development opportunities.', 5),
#  ('to handle', 5),
#  ('of electronic', 5),
#  ('application email', 5),
#  ('the job', 5),
#  ('the organization', 5),
#  ('address "click', 5),
#  ('solving skills', 5),
#  ('responsibilities:. to', 5),
#  ('and verbal', 5),
#  ('english &', 5),
#  ('in developing', 5),
#  ('teams to', 5),
#  ('only shortlisted', 5),
#  ('immediately available', 5),
#  ('new business', 5),
#  ('relevant working', 5),
#  ('resources department', 5),
#  ('qualified candidates.', 5),
#  ('who is', 5),
#  ('business in', 5),
#  ('other ad-hoc', 5),
#  ('job opportunity,', 5),
#  ('information provided', 5),
#  ('products and', 5),
#  ('query, please', 5),
#  ('please feel', 5),
#  ('in this', 5),
#  ('birthday leave', 5),
#  ('west application', 5),
#  ('to explore', 5),
#  ('. identify', 5),
#  ('job responsibilities:.', 5),
#  ('data in', 5),
#  ('security solution', 5),
#  ('of accounting', 5),
#  ('shortlisted candidates', 5),
#  ('responsibilities:. provide', 5),
#  ('professional qualification', 5),
#  ('(data collected', 5),
#  ('or to', 5),
#  ('related projects', 5),
#  ('spoken english,', 5),
#  ('"apply" button.', 5),
#  ('written &', 5),
#  ('with last', 5),
#  ('minimum of', 5),
#  ('sales and', 5),
#  ('more job', 5),
#  ('in retail', 4),
#  ('project director', 4),
#  ('an advantage;.', 4),
#  ('and love', 4),
#  ('and enhance', 4),
#  ('as assigned.', 4),
#  ('technology or', 4),
#  ('fp&a manager', 4),
#  ('and customers', 4),
#  ('annual budget', 4),
#  ('financial planning', 4),
#  ('strong business', 4),
#  ('one month', 4),
#  ('of great', 4),
#  ('and lead', 4),
#  ('that only', 4),
#  ('send cv', 4),
#  ('and market', 4),
#  ('preferred. candidate', 4),
#  ('4 years', 4),
#  ('system is', 4),
#  ('working with', 4),
#  ('years experience', 4),
#  ('to working', 4),
#  ('good understanding', 4),
#  ('listed co', 4),
#  ('to develop', 4),
#  ('and with', 4),
#  ('preferably with', 4),
#  ('in data', 4),
#  ('applicants are', 4),
#  ('to identify', 4),
#  ('clients and', 4),
#  ('in ad', 4),
#  ('or by', 4),
#  ('updated resume', 4),
#  ('on +852', 4),
#  ('team members', 4),
#  ('all information', 4),
#  ('by providing', 4),
#  ('levels of', 4),
#  ('discretionary bonus.', 4),
#  ('in mainland', 4),
#  ('and cantonese', 4),
#  ('or click', 4),
#  ('sources and', 4),
#  ('word processing.', 4),
#  ('business analysis', 4),
#  ('least 2', 4),
#  ('in chinese', 4),
#  ("the 'apply'", 4),
#  ('salary by', 4),
#  ('to deliver', 4),
#  ('to know', 4),
#  ('accounts and', 4),
#  ('focus on', 4),
#  ('more information.', 4),
#  ('in our', 4),
#  ('in &', 4),
#  ('this advertisement', 4),
#  ('know more', 4),
#  ('and procedure', 4),
#  ('stating current', 4),
#  ('call +852', 4),
#  ('is the', 4),
#  ('on request.', 4),
#  ('of it', 4),
#  ('relevant candidates', 4),
#  ('a minimum', 4),
#  ('financial control', 4),
#  ('verbal communication', 4),
#  ('expertise in', 4),
#  ('or contacted.', 4),
#  ('and drive', 4),
#  ('follow up', 4),
#  ('information. only', 4),
#  ('team, they', 4),
#  ('not limited', 4),
#  ('forecasting and', 4),
#  ("'apply now'", 4),
#  ('create a', 4),
#  ('electronic component', 4),
#  ('and interpersonal', 4),
#  ('package to', 4),
#  ('send detailed', 4),
#  ('handle full', 4),
#  ('cash flow', 4),
#  ('and contact', 4),
#  ('for products', 4),
#  ("'apply' button", 4),
#  ('resume in', 4),
#  ('highly preferred.', 4),
#  ('available date,', 4),
#  ('disciplines. minimum', 4),
#  ('technical knowledge', 4),
#  ('8 weeks', 4),
#  ('with your', 4),
#  ('sales person', 4),
#  ('the client', 4),
#  ('manager -', 4),
#  ('role please', 4),
#  ('project team', 4),
#  ('interested individuals', 4),
#  ('prepare and', 4),
#  ('individuals can', 4),
#  ('financial statement', 4),
#  ('of hk', 4),
#  ('recruitment and', 4),
#  ('love to', 4),
#  ('client accounting', 4),
#  ('benefits including', 4),
#  ('opportunity employer.', 4),
#  ('of their', 4),
#  ('the opportunity!', 4),
#  ('responsibilities:. handle', 4),
#  ('resume, available', 4),
#  ('send full', 4),
#  ('the date', 4),
#  ('with clients', 4),
#  ('and build', 4),
#  ('different stakeholders', 4),
#  ('recruitment related', 4),
#  ('account management', 4),
#  ('by em', 4),
#  ('look for', 4),
#  ('bank holiday', 4),
#  ('full paid', 4),
#  ('audit and', 4),
#  ('about this', 4),
#  ('in hong', 4),
#  ('on development', 4),
#  ('a leading', 4),
#  ('address "click.', 4),
#  ('holder of', 4),
#  ('who look', 4),
#  ('daily accounting', 4),
#  ('project manager', 4),
#  ('of various', 4),
#  ('to create', 4),
#  ('accounting services', 4),
#  ('word, excel,', 4),
#  ('can apply', 4),
#  ('experience and', 4),
#  ('this position', 4),
#  ('in building', 4),
#  ('1-2 years', 4),
#  ('limited to', 4),
#  ('high diploma', 4),
#  ('compliance with', 4),
#  ('of electronics', 4),
#  ('production run', 4),
#  ('lead the', 4),
#  ('high calibre', 4),
#  ('cyberport 2', 4),
#  ('and update', 4),
#  ('work independently.', 4),
#  ('budgeting, forecasting', 4),
#  ('to drive', 4),
#  ('big data', 4),
#  ('discussion about', 4),
#  ('or call', 4),
#  ('positive attitude', 4),
#  ('perform ad', 4),
#  ('requirements. diploma', 4),
#  ('benefits will', 4),
#  ('company. we', 4),
#  ("what you'll", 4),
#  ('the team', 4),
#  ('the successful', 4),
#  ('recruitment purpose)', 4),
#  ('ambitious career', 4),
#  ('people, now', 4),
#  ('analyst /', 4),
#  ('a must.', 4),
#  ('of relevant', 4),
#  ('welcome applications', 4),
#  ('related discipline.', 4),
#  ('and performance', 4),
#  ('team in', 4),
#  ('business partner', 4),
#  ('. f.5', 4),
#  ('provide technical', 4),
#  ('"click. here"', 4),
#  ('do not', 4),
#  ('8 years’', 4),
#  ('the management', 4),
#  ('reports and', 4),
#  ('of this', 4),
#  ('and to', 4),
#  ('date, present', 4),
#  ('for application', 4),
#  ('location :', 4),
#  ('user requirement,', 4),
#  ('various departments', 4),
#  ('market and', 4),
#  ('company website', 4),
#  ('good knowledge', 4),
#  ('. how', 4),
#  ('management solution', 4),
#  ('unsuccessful applications', 4),
#  ('services in', 4),
#  ('are interested', 4),
#  ('job offer', 4),
#  ('now and', 4),
#  ('great and', 4),
#  ('we may', 4),
#  ('+852 3972', 4),
#  ('relationship manager', 4),
#  ('sales team.', 4),
#  ('in project', 4),
#  ('global enterprise', 4),
#  ('it project', 4),
#  ('the market', 4),
#  ('it solution', 4),
#  ('the latest', 4),
#  ('candidates. interested', 4),
#  ('network infrastructure', 4),
#  ('a related', 4),
#  ('below. for', 4),
#  ('ms word,', 4),
#  ('analysis for', 4),
#  ('career advancement', 4),
#  ('and annual', 4),
#  ('now this', 4),
#  ('in java', 4),
#  ('employee relations', 4),
#  ('within 8', 4),
#  ('kept for', 4),
#  ('@bgc-group.com. *', 4),
#  ('business analyst', 4),
#  ('bay, hong', 4),
#  ('management reporting', 4),
#  ('analyst programmer', 4),
#  ('purpose only)', 4),
#  ('as the', 4),
#  ('how to', 4),
#  ('corporate banking', 4),
#  ('banking or', 4),
#  ('requirements. degree', 4),
#  ('in information', 4),
#  ('be contacted', 4),
#  ('within one', 4),
#  ('regret that', 4),
#  ('engineering a', 4),
#  ('resources &', 4),
#  ("years' experience", 4),
#  ('k per', 4),
#  ('advancement and', 4),
#  ('with over', 4),
#  ('road, kowloon', 4),
#  ('pressure and', 4),
#  ('opportunity to', 4),
#  ('strategic account', 4),
#  ('your new', 4),
#  ('a team,', 4),
#  ('an interview', 4),
#  ('accounting manager', 4),
#  ('manage and', 4),
#  ('develop new', 4),
#  ('accounting experience', 4),
#  ('competitive salary', 4),
#  ('and brilliant', 4),
#  ('*personal data', 4),
#  ('requirements:. high', 4),
#  ('six months', 4),
#  ('free to', 4),
#  ('systems an', 4),
#  ('for ambitious', 4),
#  ('financial services', 4),
#  ('and recommend', 4),
#  ('relationship management', 4),
#  ('to communicate', 4),
#  ('to china', 4),
#  ('or similar', 4),
#  ...]

# %% [markdown]
# # Training Stage: split into Sentence Array, doing one item

# %%
def lookfor(line, arr):
    for item in arr:
         if line.lower().find(item) != -1:
                return True
    return False

# %%
idx = 2
text = df["jobDetail"][idx]["jobDescription"]
pt = PrepText(text)
ajson = pt.get_variables()
ajson["sentence_arr"]
# Out:
# ['Responsible for financial & management accounts reporting and manage day-to-day accounting operations',
#  'Conduct the overall preparation of month-end, quarterly, interim and annual management reports including budgeting, forecasting and closing',
#  'Prepare consolidation accounting reports for purpose of financial accounting book closing & management accounting review',
#  'Coordinate and complete annual audits',
#  'Assist in formulating, implementing and monitoring internal and financial control policies',
#  'Support Company Secretarial matters from the financial perspective',
#  'Liaise with external auditors / consultants on interim / annual audit and tax filing',
#  'Involve in Business Valuation and other ad-hoc assignments as required']

# %%
s_arr = ajson["sentence_arr"]
collection = []
# -A requirement
# -B responsibility
# -C benefit
# -D apply resume
# -E company description
# -F others
curr_section = ""
for line in s_arr:
    if curr_section != "":
        matched = [curr_section]
    else:
        matched = []

    if lookfor(line, ["equirement", "or above", "or equivalent"]):
        curr_section = "A"
        matched.append(curr_section)

    if lookfor(line, ["description", "work on", "the role", "responsib"]):
        curr_section = "B"
        matched.append(curr_section)

    if lookfor(line, ["attractive", "competitive", "day work", "mpf", "medical", "remuneration"]):
        curr_section = "C"
        matched.append(curr_section)

    if lookfor(line, ["interested party", "resume", "apply", "more detail"]):
        curr_section = "D"
        matched.append(curr_section)

    if lookfor(line, ["our client"]):
        curr_section = "E"
        matched.append(curr_section)

    if lookfor(line, ["personal data", "personal information"]):
        curr_section = "F"
        matched.append(curr_section)

    matched = list(set(matched))

    collection.append({
        "cate": matched,
        "line": line
    })

collection
# Out:
# [{'cate': ['B'],
#   'line': 'Responsible for financial & management accounts reporting and manage day-to-day accounting operations'},
#  {'cate': ['B'],
#   'line': 'Conduct the overall preparation of month-end, quarterly, interim and annual management reports including budgeting, forecasting and closing'},
#  {'cate': ['B'],
#   'line': 'Prepare consolidation accounting reports for purpose of financial accounting book closing & management accounting review'},
#  {'cate': ['B'], 'line': 'Coordinate and complete annual audits'},
#  {'cate': ['B'],
#   'line': 'Assist in formulating, implementing and monitoring internal and financial control policies'},
#  {'cate': ['B'],
#   'line': 'Support Company Secretarial matters from the financial perspective'},
#  {'cate': ['B'],
#   'line': 'Liaise with external auditors / consultants on interim / annual audit and tax filing'},
#  {'cate': ['B'],
#   'line': 'Involve in Business Valuation and other ad-hoc assignments as required'}]

# %% [markdown]
# # Training Stage: split into Sentence Array, doing ALL training items

# %%
gcoll = []
for idx in range(len(df["jobDetail"]))[:]:
    text = df["jobDetail"][idx]["jobDescription"]
    pt = PrepText(text)
    ajson = pt.get_variables()
    ajson["sentence_arr"]
    
    s_arr = ajson["sentence_arr"]
    collection = []
    # -A requirement
    # -B responsibility
    # -C benefit
    # -D apply resume
    # -E company description
    # -F others
    curr_section = ""
    for line in s_arr:
        if curr_section != "":
            matched = [curr_section]
        else:
            matched = []

        if lookfor(line, ["equirement", "or above", "or equivalent"]):
            curr_section = "A"
            matched.append(curr_section)

        if lookfor(line, ["description", "work on", "the role", "responsib"]):
            curr_section = "B"
            matched.append(curr_section)

        if lookfor(line, ["attractive", "competitive", "day work", "mpf", "medical", "remuneration"]):
            curr_section = "C"
            matched.append(curr_section)

        if lookfor(line, ["interested party", "resume", "apply", "more detail"]):
            curr_section = "D"
            matched.append(curr_section)

        if lookfor(line, ["our client"]):
            curr_section = "E"
            matched.append(curr_section)

        if lookfor(line, ["personal data", "personal information"]):
            curr_section = "F"
            matched.append(curr_section)

        matched = list(set(matched))

        collection.append({
            "cate": matched,
            "line": line
        })

    # collection
    gcoll.append({
    "#A requirement": ' '.join([x["line"] for x in collection if "A" in x["cate"] and len(x["cate"]) == 1]),
    "#B responsibility": ' '.join([x["line"] for x in collection if "B" in x["cate"] and len(x["cate"]) == 1]),
    "#C benefit": ' '.join([x["line"] for x in collection if "C" in x["cate"] and len(x["cate"]) == 1]),
    "#D apply resume": ' '.join([x["line"] for x in collection if "D" in x["cate"] and len(x["cate"]) == 1]),
    "#E company description": ' '.join([x["line"] for x in collection if "E" in x["cate"] and len(x["cate"]) == 1]),
    "#F others": ' '.join([x["line"] for x in collection if "F" in x["cate"] and len(x["cate"]) == 1]),
    "#U unclass": ' '.join([x["line"] for x in collection if len(x["cate"]) == 0]),
    })
df_all = pd.DataFrame(gcoll)
df_all
# Out:
# [Warn]<set_lower_text>: Contains non latin characters.
# [Warn]<set_lower_text>: Contains non latin characters.
# [Warn]<set_lower_text>: Contains non latin characters.
# [Warn]<set_lower_text>: Contains non latin characters.
# [Warn]<set_lower_text>: Contains non latin characters.
#                                        #A requirement  \
# 0     Bachelor degree from Accounting and Finance ...
# 1   Ensure capital operations are compliance with ...
# 2
# 3   2 years of accounting experience (retail indus...
# 4   Be fun-loving, energetic, positive and open-mi...
# ..                                                ...
# 95
# 96  Bachelor Degree in Finance, Accounting or rela...
# 97  Degree holder is preferred Experience in Ship ...
# 98  Excellent writing, organising, presentation an...
# 99   We place much emphasis on the career developm...
#
#                                     #B responsibility  \
# 0     Responsibilities: Report to the Financial Co...
# 1
# 2   Responsible for financial & management account...
# 3   Responsibilities Handle day-to-day operations ...
# 4   Responsibilities:  Mainly responsible for dail...
# ..                                                ...
# 95    Data Communication or related disciplines • ...
# 96  Responsibilities : Reporting to the Senior Man...
# 97  Job Responsibilities Manage the purchasing pro...
# 98  Responsibilities:  Assist in copywriting, tran...
# 99  Below here are the detailed responsibilities: ...
#
#                                            #C benefit  \
# 0
# 1
# 2
# 3   Medical benefits Education Allowance Discretio...
# 4
# ..                                                ...
# 95
# 96
# 97  Monitor and handle the supply and delivery pro...
# 98
# 99
#
#                                       #D apply resume #E company description  \
# 0   For a confidential discussion about this role ...
# 1     DB Applicants are welcomed to visit our webs...
# 2
# 3                                         date to us.
# 4
# ..                                                ...                    ...
# 95
# 96  (in PDF format) with details of qualification,...
# 97   in strict confidence with your full resume, e...
# 98  - e-mail or , - 13/   F, Island Place Tower, N...
# 99  All information received will strictly be kept...
#
#                                             #F others  \
# 0
# 1    Applicants not hearing from us within 6 weeks...
# 2
# 3
# 4
# ..                                                ...
# 95
# 96   purposes in accordance with the laws and ordi...
# 97
# 98
# 99
#
#                                            #U unclass
# 0   They also have sales and trading functions wit...
# 1   Duties: Overviews daily operation of a finance...
# 2
# 3
# 4
# ..                                                ...
# 95
# 96
# 97  Arrange and administer the correct, timely and...
# 98        Summer Trainee - Corporate Communication
# 99  This role is exceptionally challenging because...
#
# [100 rows x 7 columns]

# %% [markdown]
# # Training Stage: Build Sets of Tokens

# %%
def build_sets(df, key):
    sentence = ' '.join(df[key]).lower()
    sixgrams = ngrams(sentence.split(), n)
    # for grams in sixgrams:
    #     print(grams)
    gram_arr = list(set(sixgrams))
#     result = []
#     for idx in range(len(gram_arr)):
#         word = ' '.join(gram_arr[idx])
#         aobj = (word, sentence.count(word))

#         result.append(aobj)
#     sorted(result, key=lambda x: x[1], reverse=True)
    return gram_arr

# %%
mapping = {
"A": "#A requirement",
"B": "#B responsibility",
"C": "#C benefit",
"D": "#D apply resume",
"E": "#E company description",
"F": "#F others",
"U": "#U unclass",
}

# %%
sets = {}

# %%
sets["A"] = build_sets(df_all, mapping["A"])
sets["B"] = build_sets(df_all, mapping["B"])
sets["C"] = build_sets(df_all, mapping["C"])
sets["D"] = build_sets(df_all, mapping["D"])
sets["E"] = build_sets(df_all, mapping["E"])

# %%
def wanted(sets, wanted_set):
    mapping = {
    "A": "#A requirement",
    "B": "#B responsibility",
    "C": "#C benefit",
    "D": "#D apply resume",
    "E": "#E company description",
    "F": "#F others",
    "U": "#U unclass",
    }
    all_sets = set(sets["A"]).union(set(sets["B"]), set(sets["C"]), set(sets["D"]), set(sets["E"]))
    all_common = set(sets["A"]).intersection(set(sets["B"]), set(sets["C"]), set(sets["D"]), set(sets["E"]))
    exclu_wanted = all_sets - set(sets[wanted_set])
    exclu_set = exclu_wanted.intersection(set(sets[wanted_set]))
    new_gram_arr = list(set(sets[wanted_set]) - exclu_set - all_common)

    exclu_set = set([])
    if wanted_set != "A":
        exclu_set = exclu_set.union(set(sets[wanted_set]).intersection(set(sets["A"])))
    if wanted_set != "B":
        exclu_set = exclu_set.union(set(sets[wanted_set]).intersection(set(sets["B"])))
    if wanted_set != "C":
        exclu_set = exclu_set.union(set(sets[wanted_set]).intersection(set(sets["C"])))
    if wanted_set != "D":
        exclu_set = exclu_set.union(set(sets[wanted_set]).intersection(set(sets["D"])))
    if wanted_set != "E":
        exclu_set = exclu_set.union(set(sets[wanted_set]).intersection(set(sets["E"])))
    new_gram_arr = list(set(sets[wanted_set]) - exclu_set)

    sentence = ' '.join(df_all[mapping[wanted_set]]).lower()
    result = []
    for idx in range(len(new_gram_arr)):
        word = ' '.join(new_gram_arr[idx])
        aobj = (word, sentence.count(word))

        result.append(aobj)
    return sorted(result, key=lambda x: x[1], reverse=True)

wanted(sets, "E")
# Out:
# [('our client', 28),
#  ('client is', 17),
#  ('join the', 12),
#  ('now looking', 11),
#  ('join their', 9),
#  ('client, a', 6),
#  ('our client,', 6),
#  ('are now', 6),
#  ('the world', 5),
#  ('is now', 5),
#  ('high caliber', 5),
#  ('following position:', 4),
#  ('team, they', 4),
#  ('of their', 4),
#  ('sales person', 4),
#  ('a world', 4),
#  ('high calibre', 4),
#  ('technical sales', 4),
#  ('asia team,', 3),
#  ('their strategic', 3),
#  ('strategic account', 3),
#  ('solution with', 3),
#  ('the world,', 3),
#  ('than 3000+', 3),
#  ('person to', 3),
#  ('who provide', 3),
#  ('for their', 3),
#  ('world, who', 3),
#  ('clients due', 3),
#  ('calibre for', 3),
#  ('their asia', 3),
#  ('leader of', 3),
#  ('client our', 3),
#  ('to fast', 3),
#  ('caliber and', 3),
#  ('financial analyst', 3),
#  ('enterprise clients', 3),
#  ('tier high', 3),
#  ('high end', 3),
#  ('account sales', 3),
#  ('they have', 3),
#  ('to global', 3),
#  ('employees in', 3),
#  ('end it', 3),
#  ('provide top', 3),
#  ('and ambitious', 3),
#  ('world leader', 3),
#  ('growing of', 3),
#  ('top tier', 3),
#  ('and safest', 2),
#  ('business expansion', 2),
#  ('your new', 2),
#  ('in an', 2),
#  ('a financial', 2),
#  ('caliber candidate', 2),
#  ('it industry', 2),
#  ('their expansion', 2),
#  ('team as', 2),
#  ('accounting manager', 2),
#  ('security and', 2),
#  ('cope with', 2),
#  ('safest solutions', 2),
#  ('a global', 2),
#  ('company to', 2),
#  ('ambitious strong', 2),
#  ('passionate in', 2),
#  ('currently looking', 2),
#  ('relationship managers', 2),
#  ('international presence', 2),
#  ('company our', 2),
#  ('our client:', 2),
#  ('growing team', 2),
#  ('around the', 2),
#  ('provider in', 2),
#  ('manager -', 2),
#  ('analyst to', 2),
#  ('manager to', 2),
#  ('it professional', 2),
#  ('to cope', 2),
#  ('mnc is', 2),
#  ('driving the', 2),
#  ('growth, they', 2),
#  ('their career', 2),
#  ('a multi', 2),
#  ('look after', 1),
#  ('comprehensive cross', 1),
#  ('develop best', 1),
#  ('with 2-6', 1),
#  ('mysql, basic', 1),
#  ('services firm,', 1),
#  ('multinational telecom', 1),
#  ('at branch', 1),
#  ('position: it', 1),
#  ('by their', 1),
#  ('global renowned', 1),
#  ('setting to', 1),
#  ('the gini', 1),
#  ('solution manager', 1),
#  ('permanent employment', 1),
#  ('renowned advertising', 1),
#  ('great communication', 1),
#  ('for outstanding', 1),
#  ('2-6 years', 1),
#  ('are investing', 1),
#  ('data generated', 1),
#  ('company is', 1),
#  ('have international', 1),
#  ('(retail mnc)our', 1),
#  ('brand with', 1),
#  ('in artificial', 1),
#  ('ip (presales)', 1),
#  ('are determined', 1),
#  ('and attitude', 1),
#  ('major it', 1),
#  ('income sales', 1),
#  ('player and', 1),
#  ('bank with', 1),
#  ('hr leader', 1),
#  ('frontend developers', 1),
#  ('in providing', 1),
#  ('listed in', 1),
#  ('the sales', 1),
#  ('the digital', 1),
#  ('is specialized', 1),
#  ('retailing brand', 1),
#  ('security engineering,', 1),
#  ("you'll support", 1),
#  ('new company', 1),
#  ('gini mobile', 1),
#  ('a top-tier', 1),
#  ('a data', 1),
#  ('expansion, they', 1),
#  ('developer to', 1),
#  ('position: personal', 1),
#  ('young and', 1),
#  ('to expansion,', 1),
#  ('manager (retail', 1),
#  ('world and', 1),
#  ('with core', 1),
#  ('across the', 1),
#  ('and applications', 1),
#  ('calibre to', 1),
#  ('services ranging', 1),
#  ('to high-net-worth', 1),
#  ('a prc', 1),
#  ('intelligent system', 1),
#  ('launching an', 1),
#  ("you'll work", 1),
#  ('candidates to', 1),
#  ('location: new', 1),
#  ('products with', 1),
#  ('is currently', 1),
#  ('level to', 1),
#  ('the territory', 1),
#  ('dynamic client', 1),
#  ('permanent opportunity', 1),
#  ('office location:', 1),
#  ('experienced with', 1),
#  ('serving more', 1),
#  ('from intelligent', 1),
#  ('environment permanent', 1),
#  ('home automation', 1),
#  ('solutions pleasant', 1),
#  ("knowledge you'll", 1),
#  ('stores to', 1),
#  ('for this', 1),
#  ('200 retail', 1),
#  ('to current', 1),
#  ('within their', 1),
#  ('and analyse', 1),
#  ('solutions provider', 1),
#  ('professionals to', 1),
#  ('up further', 1),
#  ('into the', 1),
#  ('finance manager', 1),
#  ('because of', 1),
#  ('and above', 1),
#  ('- fixed', 1),
#  ('customer experience', 1),
#  ('successfully listed', 1),
#  ('its expertise', 1),
#  ('marketing campaigns', 1),
#  ('a major', 1),
#  ('+ bonus', 1),
#  ('professional services', 1),
#  ('senior client', 1),
#  ('whcih directly', 1),
#  ('design customized', 1),
#  ('kong expertise', 1),
#  ('and managing', 1),
#  ('was successfully', 1),
#  ('have more', 1),
#  ('reporting line:', 1),
#  ('business, evaluating', 1),
#  ('financial firm', 1),
#  ('hk$ 30,000', 1),
#  ('employment in', 1),
#  ('are helping', 1),
#  ('headquarter, they', 1),
#  ('(5 days)', 1),
#  ('offices around', 1),
#  ('looking to', 1),
#  ('stack, from', 1),
#  ('multiple lenses', 1),
#  ('currently, because', 1),
#  ('expanding regional', 1),
#  ('their enterprise', 1),
#  ('as their', 1),
#  ('international accounting', 1),
#  ('strengthen its', 1),
#  ('and elite', 1),
#  ('have over', 1),
#  ('javascript familiarity', 1),
#  ('100 countries', 1),
#  ('a detail-minded', 1),
#  ('team setting', 1),
#  ('interested and', 1),
#  ('developing their', 1),
#  ('app into', 1),
#  ('backend/frontend framework', 1),
#  ('assistant to', 1),
#  ('client base', 1),
#  ('investments and', 1),
#  ('partner to', 1),
#  ('and around', 1),
#  ('base currently', 1),
#  ('provide coaching', 1),
#  ('and was', 1),
#  ('investing heavily', 1),
#  ('accountant, whcih', 1),
#  ('analysis manager', 1),
#  ('company working', 1),
#  ('their chatbot', 1),
#  ('to achieve', 1),
#  ('expansion within', 1),
#  ('heavily in', 1),
#  ('senior financial', 1),
#  ("world's leading", 1),
#  ('familiar with:', 1),
#  ('in planning', 1),
#  ('markets, the', 1),
#  ('will work', 1),
#  ('cross broad', 1),
#  ('an american', 1),
#  ('mindset and', 1),
#  ('basic infrastructure,', 1),
#  ('this position', 1),
#  ('further their', 1),
#  ('components of', 1),
#  ('provider, is', 1),
#  ('generated by', 1),
#  ('branch level', 1),
#  ('large mnc', 1),
#  ('/ head', 1),
#  ('company with', 1),
#  ('of security', 1),
#  ('their it', 1),
#  ('determined in', 1),
#  ('leading integrated', 1),
#  ('elite hr', 1),
#  ('wholesale growth', 1),
#  ('practices experienced', 1),
#  ('asia about', 1),
#  ('product knowledge', 1),
#  ('achieve insurance', 1),
#  ('skills be', 1),
#  ('expansion, now', 1),
#  ('firm is', 1),
#  ('current demand', 1),
#  ('firm in', 1),
#  ('and reputation', 1),
#  ('position background', 1),
#  ('and ui/ux', 1),
#  ('new territories', 1),
#  ('deliver its', 1),
#  ('studies preferred', 1),
#  ('it team', 1),
#  ('a solution', 1),
#  ('the software', 1),
#  ('detail-minded financial', 1),
#  ('businesses in', 1),
#  ('for professionals', 1),
#  ('integrated solutions', 1),
#  ('high-net-worth customers', 1),
#  ('framework develop', 1),
#  ('its bancassurance', 1),
#  ('a young', 1),
#  ('them looking', 1),
#  ('core businesses', 1),
#  ('with international', 1),
#  ('gm 25-30', 1),
#  ('(presales) to', 1),
#  ('and energetic', 1),
#  ('crm systems', 1),
#  ('will endeavor', 1),
#  ('business expansion,', 1),
#  ('developing a', 1),
#  ('for high', 1),
#  ('personal assistant', 1),
#  ('leading fmcg', 1),
#  ('american global', 1),
#  ('customers about', 1),
#  ('selling skills', 1),
#  ('to monitoring', 1),
#  ('providing network', 1),
#  ('their customer', 1),
#  ('in life', 1),
#  ('and training', 1),
#  ('now inviting', 1),
#  ('energetic team', 1),
#  ('team our', 1),
#  ('managers at', 1),
#  ('branch staffs', 1),
#  ('solution provider', 1),
#  ('tst (5', 1),
#  ('1,7,8 qualifications', 1),
#  ('in over', 1),
#  ('and gambling', 1),
#  ('it support', 1),
#  ('the marketplace', 1),
#  ('industry we', 1),
#  ('team reporting', 1),
#  ('over 50', 1),
#  ('maintain the', 1),
#  ('one backend/frontend', 1),
#  ('leader for', 1),
#  ('in tst', 1),
#  ('well-established client', 1),
#  ('70 products', 1),
#  ('a mnc', 1),
#  ('evaluating marketplace', 1),
#  ('industry energetic', 1),
#  ('mnc)our client', 1),
#  ('it solutions', 1),
#  ('retail business', 1),
#  ('systems thus,', 1),
#  ('global technology', 1),
#  ('region and', 1),
#  ('with friendly', 1),
#  ('apac and', 1),
#  ('designers, and', 1),
#  ('enterprise customers', 1),
#  ('security, system', 1),
#  ('fmcg company', 1),
#  ('the european', 1),
#  ('a partner', 1),
#  ('global leader', 1),
#  ('it products', 1),
#  ('business targets', 1),
#  ("you'll provide", 1),
#  ('position will', 1),
#  ('helping them', 1),
#  ('history they', 1),
#  ('salary: hk$', 1),
#  ('join our', 1),
#  ('ui/ux designers,', 1),
#  ('the branch', 1),
#  ('automation solution,', 1),
#  ('coaching and', 1),
#  ('days) is', 1),
#  ('very comprehensive', 1),
#  ('company due', 1),
#  ('40,000 x', 1),
#  ('the frontend', 1),
#  ('kong, they', 1),
#  ('system to', 1),
#  ('foreign bank', 1),
#  ("year's history", 1),
#  ('app work', 1),
#  ('outsourcing we', 1),
#  ('analyse the', 1),
#  ('to their', 1),
#  ('outstanding company', 1),
#  ('pacific region', 1),
#  ('with france', 1),
#  ('a well-established', 1),
#  ('inviting high', 1),
#  ('basic javascript', 1),
#  ('x 12', 1),
#  ('hotel brand.', 1),
#  ('young technical', 1),
#  ('mobile app', 1),
#  ('their insurance', 1),
#  ('services team', 1),
#  ('over 40', 1),
#  ('an outstanding', 1),
#  ('bancassurance business', 1),
#  ('network solution', 1),
#  ('staffs on', 1),
#  ('professionals who', 1),
#  ('scientist who', 1),
#  ('presence they', 1),
#  ('commercial market', 1),
#  ('new role', 1),
#  ('market share', 1),
#  ('software stack,', 1),
#  ('currently they', 1),
#  ('business service', 1),
#  ('territory through', 1),
#  ('to home', 1),
#  ('managers and', 1),
#  ('career path', 1),
#  ('growth strategies', 1),
#  ('top-tier multinational', 1),
#  ('it distributor', 1),
#  ('and currently,', 1),
#  ('an senior', 1),
#  ('and hksi', 1),
#  ('well-known global', 1),
#  ('support engineer', 1),
#  ('backend developer', 1),
#  ('talents who', 1),
#  ('solution, rfid', 1),
#  ('system integration', 1),
#  ('to set', 1),
#  ('corporation, due', 1),
#  ('in driving', 1),
#  ('outstanding companies', 1),
#  ('insurance business', 1),
#  ('service outsourcing', 1),
#  ('f&b company', 1),
#  ('to design', 1),
#  ('it professionals', 1),
#  ('the commercial', 1),
#  ('to strengthen', 1),
#  ('opportunity with', 1),
#  ('is looking', 1),
#  ('than 100', 1),
#  ('group finance', 1),
#  ('senior fp&a', 1),
#  ('thus, this', 1),
#  ('this 5-stars', 1),
#  ('regional team', 1),
#  ('an app', 1),
#  ('potential calibre', 1),
#  ('trading firm', 1),
#  ('further, they', 1),
#  ('sizable mnc', 1),
#  ('least one', 1),
#  ('deliver wealth', 1),
#  ('a well-known', 1),
#  ('analyst 25-32', 1),
#  ('for relationship', 1),
#  ('12 month', 1),
#  ('is passionate', 1),
#  ('companies in', 1),
#  ('cloud consultant', 1),
#  ('leader in', 1),
#  ('an upcoming', 1),
#  ('projects this', 1),
#  ('this will', 1),
#  ('service provider,', 1),
#  ('providing it', 1),
#  ('the apac', 1),
#  ('to gm', 1),
#  ('and self-motivating', 1),
#  ('they will', 1),
#  ('presence and', 1),
#  ('month +', 1),
#  ('iiqe 1,2,3,5', 1),
#  ('business further,', 1),
#  ("100 year's", 1),
#  ('with launching', 1),
#  ('operations great', 1),
#  ('marketplace growth', 1),
#  ('from design', 1),
#  ('their products', 1),
#  ('the key', 1),
#  ('asia pacific', 1),
#  ('& growth,', 1),
#  ('40 regional', 1),
#  ('one or', 1),
#  ('implementation to', 1),
#  ('world by', 1),
#  ('is outstanding', 1),
#  ('based financial', 1),
#  ('and driving', 1),
#  ('engineering, asia', 1),
#  ('to 40,000', 1),
#  ('sales function', 1),
#  ('methodology own', 1),
#  ('are seeking', 1),
#  ('the business,', 1),
#  ("customers you'll", 1),
#  ('50 countries', 1),
#  ('their growing', 1),
#  ('their young', 1),
#  ('specialized in', 1),
#  ('relevant studies', 1),
#  ('firm, is', 1),
#  ('branch manager', 1),
#  ('hksi 1,7,8', 1),
#  ('talented individual', 1),
#  ('seeking a', 1),
#  ('industry they', 1),
#  ('integration and', 1),
#  ('a sizable', 1),
#  ('position: financial', 1),
#  ('own one', 1),
#  ('a talented', 1),
#  ('innovative f&b', 1),
#  ('line: head', 1),
#  ('in apparel', 1),
#  ('driver in', 1),
#  ('& analysis', 1),
#  ('client: our', 1),
#  ('cloud team', 1),
#  ('agile methodology', 1),
#  ('prc based', 1),
#  ('in asia', 1),
#  ('chatbot projects', 1),
#  ('campaigns in', 1),
#  ('1,2,3,5 and', 1),
#  ('as accounting', 1),
#  ('global it', 1),
#  ('an interactive', 1),
#  ('5-stars hotel', 1),
#  ('an innovative', 1),
#  ('our project', 1),
#  ('management service', 1),
#  ('marketplace investments', 1),
#  ('services due', 1),
#  ('marketing industry', 1),
#  ('steady growth,', 1),
#  ('their team', 1),
#  ('industry to', 1),
#  ('development we', 1),
#  ('more components', 1),
#  ('business solutions', 1),
#  ('candidate for', 1),
#  ('senior backend', 1),
#  ('drive marketing', 1),
#  ('- network/', 1),
#  ('their company', 1),
#  ('demand &', 1),
#  ('countries around', 1),
#  ('as cloud', 1),
#  ('upcoming and', 1),
#  ('corporation, and', 1),
#  ('developers and', 1),
#  ('with relationship', 1),
#  ('30,000 to', 1),
#  ("person: bachelor's", 1),
#  ('through multiple', 1),
#  ('leading entertainment', 1),
#  ('customized solutions', 1),
#  ('insurance selling', 1),
#  ('reputation for', 1),
#  ('a potential', 1),
#  ('their headquarter,', 1),
#  ('calibre senior', 1),
#  ('cyber security,', 1),
#  ('strategies across', 1),
#  ('a large', 1),
#  ('interactive team', 1),
#  ('job: work', 1),
#  ('design to', 1),
#  ('leading foreign', 1),
#  ('managing the', 1),
#  ('over 100', 1),
#  ('to look', 1),
#  ('life insurance', 1),
#  ('experience team,', 1),
#  ('outstanding talents', 1),
#  ('than 70', 1),
#  ('it professional,', 1),
#  ('further strategies', 1),
#  ('on their', 1),
#  ('function in', 1),
#  ('advertising company', 1),
#  ("a world's", 1),
#  ("role you'll", 1),
#  ('their crm', 1),
#  ('around 200', 1),
#  ('hk they', 1),
#  ('will allow', 1),
#  ('ranging from', 1),
#  ('an accountant,', 1),
#  ('environment our', 1),
#  ('applications development', 1),
#  ('development familiar', 1),
#  ('multi national', 1),
#  ('endeavor to', 1),
#  ('their dynamic', 1),
#  ('and passionate', 1),
#  ('france as', 1),
#  ('path in', 1),
#  ('expansion the', 1),
#  ('background permanent', 1),
#  ('providing very', 1),
#  ('new emerging', 1),
#  ('the growing', 1),
#  ('self-motivating mindset', 1),
#  ('regional offices', 1),
#  ('infrastructure, basic', 1),
#  ('key driver', 1),
#  ('the wholesale', 1),
#  ('leading retailing', 1),
#  ('developing further', 1),
#  ('with: mysql,', 1),
#  ('products in', 1),
#  ('rfid and', 1),
#  ('with iiqe', 1),
#  ('the expanding', 1),
#  ('senior merchandiser', 1),
#  ('training for', 1),
#  ('caliber candidates', 1),
#  ('increase market', 1),
#  ('distributor serving', 1),
#  ('their steady', 1),
#  ('data scientist', 1),
#  ('national company', 1),
#  ('allow the', 1),
#  ('join them', 1),
#  ('the new', 1),
#  ('gambling corporation,', 1),
#  ('other branch', 1),
#  ('technology company', 1),
#  ('familiarity with', 1),
#  ('degree and', 1),
#  ('client, an', 1),
#  ('entertainment and', 1),
#  ('mnc corporation,', 1),
#  ('multinational trading', 1),
#  ('solution due', 1),
#  ('them as', 1),
#  ('energetic cloud', 1),
#  ('the job:', 1),
#  ('expansion in', 1),
#  ('with their', 1),
#  ('hong kong,', 1),
#  ('career with', 1),
#  ('consistent career', 1),
#  ('artificial intelligence', 1),
#  ('apparel industry', 1),
#  ('broad it', 1),
#  ('under agile', 1),
#  ('telecom providing', 1),
#  ('countries we', 1),
#  ('european leading', 1),
#  ('emerging markets,', 1),
#  ('person as', 1),
#  ('manager salary:', 0),
#  ('team senior', 0),
#  ('background act', 0),
#  ('insurance proactive', 0),
#  ('k our', 0),
#  ('3000+ employees', 0),
#  ('brand. our', 0),
#  ('business position', 0),
#  ('qualifications solid', 0),
#  ('growth our', 0),
#  ('targets what', 0),
#  ('us our', 0),
#  ('position: general', 0),
#  ('attitude about', 0),
#  ('25-32 k', 0),
#  ('sales our', 0),
#  ('k your', 0),
#  ('bonus office', 0),
#  ('succeed degree', 0),
#  ('network/ ip', 0),
#  ('lenses act', 0),
#  ('engineer our', 0),
#  ('manager our', 0),
#  ('team about', 0),
#  ('merchandiser our', 0),
#  ('professional, who', 0),
#  ('consultant to', 0),
#  ('share your', 0),
#  ('25-30 k', 0),
#  ('strategies our', 0),
#  ('market currently', 0),
#  ('learn the', 0),
#  ('territories our', 0)]

# %% [markdown]
# # Training Stage: testing mutually exclusive of token in different sets

# %%
token = wanted(sets, "E")[15][0]
list(filter(lambda x: x[0] == token, all_2grams))
# Out:
# [('a world', 5)]

# %%
len(all_2grams)
# Out:
# 11873

# %%
{
    "word": token,
    "A": tuple(token.split()) in sets["A"],
    "B": tuple(token.split()) in sets["B"],
    "C": tuple(token.split()) in sets["C"],
    "D": tuple(token.split()) in sets["D"],
    "E": tuple(token.split()) in sets["E"],
}
# Out:
# {'word': 'a world', 'A': False, 'B': False, 'C': False, 'D': False, 'E': True}

# %% [markdown]
# # Training Stage: Build token dictionary of each section

# %%
wA = wanted(sets, "A")
wB = wanted(sets, "B")
wC = wanted(sets, "C")
wD = wanted(sets, "D")
wE = wanted(sets, "E")

# %% [markdown]
# # Testing Stage: Labelling a Job Ads with guessing section using testing Datasets

# %%
df400 = get_df("./jobsdb_dump_400-500.json")

idx = 64
text = df400["jobDetail"][idx]["jobDescription"]
text = PrepText(text).get_variables()["lower_text"]
text
# Out:
# "a world leading sourcing office is currently looking for a senior merchandiser (outdoor furniture) to join their dynamic team.   client details.   our client is one of the european leading fmcg company. due to their steady growth, they are now looking for a potential calibre to join the expanding regional team as a senior merchandiser.   description keep track with the orders delivery schedules.   source and develop new product range according to buying brief.   work with suppliers to resolve quality concerns and production schedule concerns.   monitor daily operation, including sourcing, sampling, price negotiation and project set up.   work closely with other departments including quality control and shipping for updating the quality standard and shipment status.   coordinate with factories to ensure timely deliveries profile.   f.5 or above qualification.   proactive and well organised.   good communication and negotiation skills to work with clients and suppliers.   business english and mandarin.   relevant merchandising experience in outdoor furniture/ home items.   job offer.   excellent career promotion is greatly promised to the right candidate. our client offers an attractive remuneration package of monthly salary + attractive year-end bonus, depending on performance. please call at +852 3602 2493 for more details.   international career prospects.   competitive salary.   medical coverage.   mpf5-day work week.   to apply online please click the 'apply' button below. for a confidential discussion about this role please contact [kenneth] [leung] on [+852 3602 2493]."

# %%
total_token_count = len(all_2grams)
collection = []
for i in range(len(text.split())-2):
    token = ' '.join(text.split()[i:i+2])
    # print(token)
    term_in_section = []
    probability = []
    lsA = list(filter(lambda x: x[0] == token, wA))
    lsB = list(filter(lambda x: x[0] == token, wB))
    lsC = list(filter(lambda x: x[0] == token, wC))
    lsD = list(filter(lambda x: x[0] == token, wD))
    lsE = list(filter(lambda x: x[0] == token, wE))

    if len(lsA) > 0:
        term_in_section.append({"key": "A", "prob": lsA[0][1] / total_token_count})
    if len(lsB) > 0:
        term_in_section.append({"key": "B", "prob": lsB[0][1] / total_token_count})
    if len(lsC) > 0:
        term_in_section.append({"key": "C", "prob": lsC[0][1] / total_token_count})
    if len(lsD) > 0:
        term_in_section.append({"key": "D", "prob": lsD[0][1] / total_token_count})
    if len(lsE) > 0:
        term_in_section.append({"key": "E", "prob": lsE[0][1] / total_token_count})
    collection.append({
        "token": token,
        "in": term_in_section,
    })
ajson = json.dumps(collection)
with open("tagged_section.json", mode="w") as f:
    f.write(ajson)
# collection

# %% [markdown]
# # Testing Stage: Output HTML of section tagging

# %%
ajson = json.dumps(collection)

with open("tagged_section.html", mode="w", encoding="utf8") as f:
    mapping_color = {
        "A": "red",
        "B": "orange",
        "C": "blue",
        "D": "green",
        "E": "#FF00FF",
    }
    resultHTML = ""
    for legend in mapping_color.keys():
        resultHTML = resultHTML + f'<p><span style="color: {mapping_color[legend]};">{mapping[legend]}</span></p>'
    resultHTML = resultHTML + '<hr>'
        
    for o in collection:
        word = o["token"].split(" ")[0];
        color = ""
        if len(o["in"]) > 0:
            if True or o["in"][0]["prob"] > (1/total_token_count):
                color = mapping_color[o["in"][0]["key"]]
            
        print(o)

        resultHTML = resultHTML + f'<span style="color: {color};">{word}</span> '
        if word.find(".") != -1:
            resultHTML = resultHTML + '<br>'
            
    lastItem = collection[len(collection) -1 ]
    word = lastItem["token"].split(" ")[1];
    color = ""
    if len(lastItem["in"]) > 0:
        color = mapping_color[lastItem["in"][0]["key"]]
    resultHTML = resultHTML + f'<span style="color: {color};">{word}</span> '

    
    js_version = """<!DOCTYPE html>
<html>
<head>
<meta charset="utf-8">
<title>Tagged Job Ads section</title>
<script>
window.ajson = """ + ajson + """;
</script>
</head>

<body>
<h1>Tagged Job Ads section</h1>
<div id="tags">

</div>

<script>
let tagsEl = document.querySelector("#tags");
let resultHTML = "";
let mapping_color = {
    "A": "red",
    "B": "orange",
    "C": "blue",
    "D": "green",
    "E": "#FF00FF",
    "Other": ""
}

window.ajson.map((o) => {
    let word = o["token"].split(" ")[0];
    let color = ""
    if (o["in"].length > 0) {
        if (true || o["in"][0]["prob"] > (1/""" + str(total_token_count) + """)) {
            color = mapping_color[o["in"][0]["key"]];
        }
    }
    resultHTML += `<span style="color: ${color};">${word}</span> `
    if (word.indexOf(".") != -1) {
        resultHTML += `<br>`
    }
})


let lastItem = window.ajson[window.ajson.length-1]
word = lastItem["token"].split(" ")[1];
color = ""
if (lastItem["in"].length > 0) {
    color = mapping_color[lastItem["in"][0]["key"]];
}
resultHTML += `<span style="color: ${color};">${word}</span> `

tagsEl.innerHTML = resultHTML;
</script>
</body>
</html>
    """
    pre_gen_version = """
    <div id="tags">
    """ + resultHTML + """
</div>
    """
    f.write(js_version)
# Out:
# {'token': 'a world', 'in': [{'key': 'E', 'prob': 0.000336898846121452}]}
# {'token': 'world leading', 'in': []}
# {'token': 'leading sourcing', 'in': []}
# {'token': 'sourcing office', 'in': []}
# {'token': 'office is', 'in': []}
# {'token': 'is currently', 'in': [{'key': 'E', 'prob': 8.4224711530363e-05}]}
# {'token': 'currently looking', 'in': [{'key': 'E', 'prob': 0.000168449423060726}]}
# {'token': 'looking for', 'in': []}
# {'token': 'for a', 'in': []}
# {'token': 'a senior', 'in': []}
# {'token': 'senior merchandiser', 'in': [{'key': 'E', 'prob': 8.4224711530363e-05}]}
# {'token': 'merchandiser (outdoor', 'in': []}
# {'token': '(outdoor furniture)', 'in': []}
# {'token': 'furniture) to', 'in': []}
# {'token': 'to join', 'in': []}
# {'token': 'join their', 'in': [{'key': 'E', 'prob': 0.0007580224037732671}]}
# {'token': 'their dynamic', 'in': [{'key': 'E', 'prob': 8.4224711530363e-05}]}
# {'token': 'dynamic team.', 'in': []}
# {'token': 'team. client', 'in': []}
# {'token': 'client details.', 'in': []}
# {'token': 'details. our', 'in': []}
# {'token': 'our client', 'in': [{'key': 'E', 'prob': 0.002358291922850164}]}
# {'token': 'client is', 'in': [{'key': 'E', 'prob': 0.0014318200960161712}]}
# {'token': 'is one', 'in': []}
# {'token': 'one of', 'in': []}
# {'token': 'of the', 'in': []}
# {'token': 'the european', 'in': [{'key': 'E', 'prob': 8.4224711530363e-05}]}
# {'token': 'european leading', 'in': [{'key': 'E', 'prob': 8.4224711530363e-05}]}
# {'token': 'leading fmcg', 'in': [{'key': 'E', 'prob': 8.4224711530363e-05}]}
# {'token': 'fmcg company.', 'in': []}
# {'token': 'company. due', 'in': []}
# {'token': 'due to', 'in': []}
# {'token': 'to their', 'in': [{'key': 'E', 'prob': 8.4224711530363e-05}]}
# {'token': 'their steady', 'in': [{'key': 'E', 'prob': 8.4224711530363e-05}]}
# {'token': 'steady growth,', 'in': [{'key': 'E', 'prob': 8.4224711530363e-05}]}
# {'token': 'growth, they', 'in': [{'key': 'E', 'prob': 0.000168449423060726}]}
# {'token': 'they are', 'in': []}
# {'token': 'are now', 'in': [{'key': 'E', 'prob': 0.000505348269182178}]}
# {'token': 'now looking', 'in': [{'key': 'E', 'prob': 0.0009264718268339931}]}
# {'token': 'looking for', 'in': []}
# {'token': 'for a', 'in': []}
# {'token': 'a potential', 'in': [{'key': 'E', 'prob': 8.4224711530363e-05}]}
# {'token': 'potential calibre', 'in': [{'key': 'E', 'prob': 8.4224711530363e-05}]}
# {'token': 'calibre to', 'in': [{'key': 'E', 'prob': 8.4224711530363e-05}]}
# {'token': 'to join', 'in': []}
# {'token': 'join the', 'in': [{'key': 'E', 'prob': 0.001010696538364356}]}
# {'token': 'the expanding', 'in': [{'key': 'E', 'prob': 8.4224711530363e-05}]}
# {'token': 'expanding regional', 'in': [{'key': 'E', 'prob': 8.4224711530363e-05}]}
# {'token': 'regional team', 'in': [{'key': 'E', 'prob': 8.4224711530363e-05}]}
# {'token': 'team as', 'in': [{'key': 'E', 'prob': 0.000168449423060726}]}
# {'token': 'as a', 'in': []}
# {'token': 'a senior', 'in': []}
# {'token': 'senior merchandiser.', 'in': []}
# {'token': 'merchandiser. description', 'in': []}
# {'token': 'description keep', 'in': []}
# {'token': 'keep track', 'in': []}
# {'token': 'track with', 'in': []}
# {'token': 'with the', 'in': []}
# {'token': 'the orders', 'in': []}
# {'token': 'orders delivery', 'in': []}
# {'token': 'delivery schedules.', 'in': []}
# {'token': 'schedules. source', 'in': []}
# {'token': 'source and', 'in': [{'key': 'B', 'prob': 8.4224711530363e-05}]}
# {'token': 'and develop', 'in': []}
# {'token': 'develop new', 'in': [{'key': 'B', 'prob': 0.000168449423060726}]}
# {'token': 'new product', 'in': [{'key': 'B', 'prob': 0.000168449423060726}]}
# {'token': 'product range', 'in': [{'key': 'B', 'prob': 8.4224711530363e-05}]}
# {'token': 'range according', 'in': [{'key': 'B', 'prob': 8.4224711530363e-05}]}
# {'token': 'according to', 'in': [{'key': 'B', 'prob': 0.000336898846121452}]}
# {'token': 'to buying', 'in': [{'key': 'B', 'prob': 8.4224711530363e-05}]}
# {'token': 'buying brief.', 'in': []}
# {'token': 'brief. work', 'in': []}
# {'token': 'work with', 'in': []}
# {'token': 'with suppliers', 'in': []}
# {'token': 'suppliers to', 'in': [{'key': 'B', 'prob': 0.000168449423060726}]}
# {'token': 'to resolve', 'in': [{'key': 'B', 'prob': 8.4224711530363e-05}]}
# {'token': 'resolve quality', 'in': [{'key': 'B', 'prob': 8.4224711530363e-05}]}
# {'token': 'quality concerns', 'in': [{'key': 'B', 'prob': 8.4224711530363e-05}]}
# {'token': 'concerns and', 'in': [{'key': 'B', 'prob': 8.4224711530363e-05}]}
# {'token': 'and production', 'in': []}
# {'token': 'production schedule', 'in': [{'key': 'B', 'prob': 8.4224711530363e-05}]}
# {'token': 'schedule concerns.', 'in': []}
# {'token': 'concerns. monitor', 'in': []}
# {'token': 'monitor daily', 'in': [{'key': 'B', 'prob': 8.4224711530363e-05}]}
# {'token': 'daily operation,', 'in': [{'key': 'B', 'prob': 8.4224711530363e-05}]}
# {'token': 'operation, including', 'in': [{'key': 'B', 'prob': 8.4224711530363e-05}]}
# {'token': 'including sourcing,', 'in': [{'key': 'B', 'prob': 8.4224711530363e-05}]}
# {'token': 'sourcing, sampling,', 'in': [{'key': 'B', 'prob': 0.000168449423060726}]}
# {'token': 'sampling, price', 'in': [{'key': 'B', 'prob': 8.4224711530363e-05}]}
# {'token': 'price negotiation', 'in': [{'key': 'B', 'prob': 8.4224711530363e-05}]}
# {'token': 'negotiation and', 'in': []}
# {'token': 'and project', 'in': []}
# {'token': 'project set', 'in': [{'key': 'B', 'prob': 8.4224711530363e-05}]}
# {'token': 'set up.', 'in': []}
# {'token': 'up. work', 'in': []}
# {'token': 'work closely', 'in': []}
# {'token': 'closely with', 'in': []}
# {'token': 'with other', 'in': []}
# {'token': 'other departments', 'in': [{'key': 'B', 'prob': 8.4224711530363e-05}]}
# {'token': 'departments including', 'in': [{'key': 'B', 'prob': 8.4224711530363e-05}]}
# {'token': 'including quality', 'in': [{'key': 'B', 'prob': 8.4224711530363e-05}]}
# {'token': 'quality control', 'in': []}
# {'token': 'control and', 'in': [{'key': 'B', 'prob': 0.000168449423060726}]}
# {'token': 'and shipping', 'in': [{'key': 'B', 'prob': 8.4224711530363e-05}]}
# {'token': 'shipping for', 'in': [{'key': 'B', 'prob': 8.4224711530363e-05}]}
# {'token': 'for updating', 'in': [{'key': 'B', 'prob': 8.4224711530363e-05}]}
# {'token': 'updating the', 'in': [{'key': 'B', 'prob': 8.4224711530363e-05}]}
# {'token': 'the quality', 'in': [{'key': 'B', 'prob': 8.4224711530363e-05}]}
# {'token': 'quality standard', 'in': [{'key': 'B', 'prob': 0.000168449423060726}]}
# {'token': 'standard and', 'in': [{'key': 'B', 'prob': 8.4224711530363e-05}]}
# {'token': 'and shipment', 'in': [{'key': 'B', 'prob': 8.4224711530363e-05}]}
# {'token': 'shipment status.', 'in': []}
# {'token': 'status. coordinate', 'in': []}
# {'token': 'coordinate with', 'in': []}
# {'token': 'with factories', 'in': [{'key': 'B', 'prob': 8.4224711530363e-05}]}
# {'token': 'factories to', 'in': [{'key': 'B', 'prob': 0.000168449423060726}]}
# {'token': 'to ensure', 'in': []}
# {'token': 'ensure timely', 'in': [{'key': 'B', 'prob': 0.000168449423060726}]}
# {'token': 'timely deliveries', 'in': [{'key': 'B', 'prob': 8.4224711530363e-05}]}
# {'token': 'deliveries profile.', 'in': []}
# {'token': 'profile. f.5', 'in': []}
# {'token': 'f.5 or', 'in': []}
# {'token': 'or above', 'in': [{'key': 'A', 'prob': 0.0018529436536679862}]}
# {'token': 'above qualification.', 'in': []}
# {'token': 'qualification. proactive', 'in': []}
# {'token': 'proactive and', 'in': []}
# {'token': 'and well', 'in': [{'key': 'A', 'prob': 8.4224711530363e-05}]}
# {'token': 'well organised.', 'in': []}
# {'token': 'organised. good', 'in': []}
# {'token': 'good communication', 'in': []}
# {'token': 'communication and', 'in': []}
# {'token': 'and negotiation', 'in': [{'key': 'A', 'prob': 0.000252674134591089}]}
# {'token': 'negotiation skills', 'in': [{'key': 'A', 'prob': 0.000168449423060726}]}
# {'token': 'skills to', 'in': []}
# {'token': 'to work', 'in': []}
# {'token': 'work with', 'in': []}
# {'token': 'with clients', 'in': []}
# {'token': 'clients and', 'in': []}
# {'token': 'and suppliers.', 'in': []}
# {'token': 'suppliers. business', 'in': []}
# {'token': 'business english', 'in': [{'key': 'A', 'prob': 8.4224711530363e-05}]}
# {'token': 'english and', 'in': []}
# {'token': 'and mandarin.', 'in': []}
# {'token': 'mandarin. relevant', 'in': []}
# {'token': 'relevant merchandising', 'in': [{'key': 'A', 'prob': 8.4224711530363e-05}]}
# {'token': 'merchandising experience', 'in': [{'key': 'A', 'prob': 8.4224711530363e-05}]}
# {'token': 'experience in', 'in': []}
# {'token': 'in outdoor', 'in': [{'key': 'A', 'prob': 8.4224711530363e-05}]}
# {'token': 'outdoor furniture/', 'in': [{'key': 'A', 'prob': 8.4224711530363e-05}]}
# {'token': 'furniture/ home', 'in': [{'key': 'A', 'prob': 8.4224711530363e-05}]}
# {'token': 'home items.', 'in': []}
# {'token': 'items. job', 'in': []}
# {'token': 'job offer.', 'in': []}
# {'token': 'offer. excellent', 'in': []}
# {'token': 'excellent career', 'in': []}
# {'token': 'career promotion', 'in': [{'key': 'A', 'prob': 8.4224711530363e-05}]}
# {'token': 'promotion is', 'in': [{'key': 'A', 'prob': 8.4224711530363e-05}]}
# {'token': 'is greatly', 'in': [{'key': 'A', 'prob': 8.4224711530363e-05}]}
# {'token': 'greatly promised', 'in': [{'key': 'A', 'prob': 8.4224711530363e-05}]}
# {'token': 'promised to', 'in': [{'key': 'A', 'prob': 8.4224711530363e-05}]}
# {'token': 'to the', 'in': []}
# {'token': 'the right', 'in': []}
# {'token': 'right candidate.', 'in': []}
# {'token': 'candidate. our', 'in': []}
# {'token': 'our client', 'in': [{'key': 'E', 'prob': 0.002358291922850164}]}
# {'token': 'client offers', 'in': []}
# {'token': 'offers an', 'in': []}
# {'token': 'an attractive', 'in': [{'key': 'C', 'prob': 8.4224711530363e-05}]}
# {'token': 'attractive remuneration', 'in': [{'key': 'C', 'prob': 8.4224711530363e-05}]}
# {'token': 'remuneration package', 'in': [{'key': 'C', 'prob': 8.4224711530363e-05}]}
# {'token': 'package of', 'in': []}
# {'token': 'of monthly', 'in': [{'key': 'B', 'prob': 0.000168449423060726}]}
# {'token': 'monthly salary', 'in': []}
# {'token': 'salary +', 'in': [{'key': 'B', 'prob': 8.4224711530363e-05}]}
# {'token': '+ attractive', 'in': []}
# {'token': 'attractive year-end', 'in': []}
# {'token': 'year-end bonus,', 'in': []}
# {'token': 'bonus, depending', 'in': []}
# {'token': 'depending on', 'in': [{'key': 'A', 'prob': 8.4224711530363e-05}]}
# {'token': 'on performance.', 'in': []}
# {'token': 'performance. please', 'in': []}
# {'token': 'please call', 'in': [{'key': 'A', 'prob': 8.4224711530363e-05}]}
# {'token': 'call at', 'in': []}
# {'token': 'at +852', 'in': []}
# {'token': '+852 3602', 'in': []}
# {'token': '3602 2493', 'in': []}
# {'token': '2493 for', 'in': []}
# {'token': 'for more', 'in': []}
# {'token': 'more details.', 'in': []}
# {'token': 'details. international', 'in': []}
# {'token': 'international career', 'in': [{'key': 'D', 'prob': 8.4224711530363e-05}]}
# {'token': 'career prospects.', 'in': []}
# {'token': 'prospects. competitive', 'in': []}
# {'token': 'competitive salary.', 'in': []}
# {'token': 'salary. medical', 'in': []}
# {'token': 'medical coverage.', 'in': []}
# {'token': 'coverage. mpf5-day', 'in': []}
# {'token': 'mpf5-day work', 'in': [{'key': 'C', 'prob': 8.4224711530363e-05}]}
# {'token': 'work week.', 'in': []}
# {'token': 'week. to', 'in': []}
# {'token': 'to apply', 'in': [{'key': 'D', 'prob': 8.4224711530363e-05}]}
# {'token': 'apply online', 'in': []}
# {'token': 'online please', 'in': []}
# {'token': 'please click', 'in': [{'key': 'D', 'prob': 8.4224711530363e-05}]}
# {'token': 'click the', 'in': [{'key': 'D', 'prob': 8.4224711530363e-05}]}
# {'token': "the 'apply'", 'in': []}
# {'token': "'apply' button", 'in': []}
# {'token': 'button below.', 'in': []}
# {'token': 'below. for', 'in': []}
# {'token': 'for a', 'in': []}
# {'token': 'a confidential', 'in': [{'key': 'D', 'prob': 0.000336898846121452}]}
# {'token': 'confidential discussion', 'in': [{'key': 'D', 'prob': 0.000336898846121452}]}
# {'token': 'discussion about', 'in': [{'key': 'D', 'prob': 0.000336898846121452}]}
# {'token': 'about this', 'in': [{'key': 'D', 'prob': 0.000336898846121452}]}
# {'token': 'this role', 'in': []}
# {'token': 'role please', 'in': [{'key': 'D', 'prob': 0.000336898846121452}]}
# {'token': 'please contact', 'in': [{'key': 'D', 'prob': 0.00042112355765181505}]}
# {'token': 'contact [kenneth]', 'in': [{'key': 'D', 'prob': 8.4224711530363e-05}]}
# {'token': '[kenneth] [leung]', 'in': [{'key': 'D', 'prob': 8.4224711530363e-05}]}
# {'token': '[leung] on', 'in': [{'key': 'D', 'prob': 8.4224711530363e-05}]}
# {'token': 'on [+852', 'in': [{'key': 'D', 'prob': 8.4224711530363e-05}]}
# {'token': '[+852 3602', 'in': [{'key': 'D', 'prob': 8.4224711530363e-05}]}

# %%
display(HTML(pre_gen_version))
# Out:
#     <div id="tags">
#     <p><span style="color: red;">#A requirement</span></p><p><span style="color: orange;">#B responsibility</span></p><p><span style="color: blue;">#C benefit</span></p><p><span style="color: green;">#D apply resume</span></p><p><span style="color: #FF00FF;">#E company description</span></p><hr><span style="color: #FF00FF;">a</span> <span style="color: ;">world</span> <span style="color: ;">leading</span> <span style="color: ;">sourcing</span> <span style="color: ;">office</span> <span style="color: #FF00FF;">is</span> <span style="color: #FF00FF;">currently</span> <span style="color: ;">looking</span> <span style="color: ;">for</span> <span style="color: ;">a</span> <span style="color: #FF00FF;">senior</span> <span style="color: ;">merchandiser</span> <span style="color: ;">(outdoor</span> <span style="color: ;">furniture)</span> <span style="color: ;">to</span> <span style="color: #FF00FF;">join</span> <span style="color: #FF00FF;">their</span> <span style="color: ;">dynamic</span> <span style="color: ;">team.</span> <br><span style="color: ;">client</span> <span style="color: ;">details.</span> <br><span style="color: #FF00FF;">our</span> <span style="color: #FF00FF;">client</span> <span style="color: ;">is</span> <span style="color: ;">one</span> <span style="color: ;">of</span> <span style="color: #FF00FF;">the</span> <span style="color: #FF00FF;">european</span> <span style="color: #FF00FF;">leading</span> <span style="color: ;">fmcg</span> <span style="color: ;">company.</span> <br><span style="color: ;">due</span> <span style="color: #FF00FF;">to</span> <span style="color: #FF00FF;">their</span> <span style="color: #FF00FF;">steady</span> <span style="color: #FF00FF;">growth,</span> <span style="color: ;">they</span> <span style="color: #FF00FF;">are</span> <span style="color: #FF00FF;">now</span> <span style="color: ;">looking</span> <span style="color: ;">for</span> <span style="color: #FF00FF;">a</span> <span style="color: #FF00FF;">potential</span> <span style="color: #FF00FF;">calibre</span> <span style="color: ;">to</span> <span style="color: #FF00FF;">join</span> <span style="color: #FF00FF;">the</span> <span style="color: #FF00FF;">expanding</span> <span style="color: #FF00FF;">regional</span> <span style="color: #FF00FF;">team</span> <span style="color: ;">as</span> <span style="color: ;">a</span> <span style="color: ;">senior</span> <span style="color: ;">merchandiser.</span> <br><span style="color: ;">description</span> <span style="color: ;">keep</span> <span style="color: ;">track</span> <span style="color: ;">with</span> <span style="color: ;">the</span> <span style="color: ;">orders</span> <span style="color: ;">delivery</span> <span style="color: ;">schedules.</span> <br><span style="color: orange;">source</span> <span style="color: ;">and</span> <span style="color: orange;">develop</span> <span style="color: orange;">new</span> <span style="color: orange;">product</span> <span style="color: orange;">range</span> <span style="color: orange;">according</span> <span style="color: orange;">to</span> <span style="color: ;">buying</span> <span style="color: ;">brief.</span> <br><span style="color: ;">work</span> <span style="color: ;">with</span> <span style="color: orange;">suppliers</span> <span style="color: orange;">to</span> <span style="color: orange;">resolve</span> <span style="color: orange;">quality</span> <span style="color: orange;">concerns</span> <span style="color: ;">and</span> <span style="color: orange;">production</span> <span style="color: ;">schedule</span> <span style="color: ;">concerns.</span> <br><span style="color: orange;">monitor</span> <span style="color: orange;">daily</span> <span style="color: orange;">operation,</span> <span style="color: orange;">including</span> <span style="color: orange;">sourcing,</span> <span style="color: orange;">sampling,</span> <span style="color: orange;">price</span> <span style="color: ;">negotiation</span> <span style="color: ;">and</span> <span ...

# %%
# End
